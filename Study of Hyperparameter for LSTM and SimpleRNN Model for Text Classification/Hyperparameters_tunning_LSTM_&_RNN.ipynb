# %%
pip uninstall tensorflow -y
# Out:
# Found existing installation: tensorflow 2.14.0
# Uninstalling tensorflow-2.14.0:
#   Successfully uninstalled tensorflow-2.14.0

# %%
pip install tensorflow==2.12.0

# %%
import re
import nltk
import random
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dropout, Dense, GlobalAveragePooling1D, SimpleRNN
from sklearn.model_selection import RandomizedSearchCV
from keras.wrappers.scikit_learn import KerasClassifier

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **IMDb Dataset**

# %%
dataset ='/content/gdrive/My Drive/Colab Notebooks/IMBD_Dataset/IMDB Dataset.csv'
df = pd.read_csv(dataset)
df.sentiment = [1 if s == 'positive' else 0 for s in df.sentiment]

# %% [markdown]
# **Preprocessing**

# %%
nltk.download('punkt')
nltk.download('stopwords')
idx = random.randint(0, len(df)-1)
before_process = df.iloc[idx][0]

def process(x):
    x = re.sub('[,\.!?:()"]', '', x)
    x = re.sub('<.*?>', ' ', x)
    x = re.sub('http\S+', ' ', x)
    x = re.sub('[^a-zA-Z0-9]', ' ', x)
    x = re.sub('\s+', ' ', x)
    return x.lower().strip()

df['review'] = df['review'].apply(lambda x: process(x))
after_process = df.iloc[idx][0]

sw_set = set(nltk.corpus.stopwords.words('english'))

def sw_remove(x):
    words = nltk.tokenize.word_tokenize(x)
    filtered_list = [word for word in words if word not in sw_set]
    return ' '.join(filtered_list)

df['review'] = df['review'].apply(lambda x: sw_remove(x))
after_removal = sw_remove(after_process)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# **Tokenization and Padding**

# %%
train_rev, test_rev, train_sent, test_sent = train_test_split(df['review'], df['sentiment'], test_size=0.1, random_state=42)

dict_size = 35000
tokenizer = Tokenizer(num_words=dict_size)
tokenizer.fit_on_texts(df['review'])

train_rev_tokens = tokenizer.texts_to_sequences(train_rev)
test_rev_tokens = tokenizer.texts_to_sequences(test_rev)
seq_lengths =  np.array([len(sequence) for sequence in train_rev_tokens])

upper_bound = int(np.mean(seq_lengths) + 2 * np.std(seq_lengths))
percentage = stats.percentileofscore(seq_lengths, upper_bound)

train_rev_pad = pad_sequences(train_rev_tokens, maxlen=upper_bound)
test_rev_pad = pad_sequences(test_rev_tokens, maxlen=upper_bound)
idx_pad = random.randint(0, len(train_rev_pad)-1)

# %% [markdown]
# **GloVe Embedding**

# %%
glove_path = '/content/gdrive/My Drive/Colab Notebooks/glove.6B/glove.6B.100d.txt'


def create_embedding_matrix(embedding_path, word_index, embedding_dim):
    embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
    print("Embedding matrix shape: %s" % str(embedding_matrix.shape))

    with open(embedding_path, encoding="utf8") as f:
        for line in f:
            values = line.split()
            word = values[0]
            if word in word_index:
                idx = word_index[word]
                embedding_matrix[idx] = np.array(values[1:], dtype="float32")
            return embedding_matrix

embedding_dimension =100
embedding_matrix = create_embedding_matrix(glove_path, tokenizer.word_index, embedding_dimension)
# Out:
# Embedding matrix shape: (125792, 100)

# %% [markdown]
# **Tuning Hyper parameters of LSTM Model**

# %%
validation_split = 0.2
batch_size = 50
epochs = 5

# Define a function to create the model
def create_model(state_dim, learning_rate, dropout_rate, batch_size, epochs):
     model = Sequential()
     model.add(Embedding(len(tokenizer.word_index)+1, embedding_dimension, input_length=upper_bound, weights=[embedding_matrix], trainable=True, mask_zero=True))
     model.add(LSTM(state_dim, return_sequences=True))
     model.add(GlobalAveragePooling1D())
     model.add(Dropout(dropout_rate))
     model.add(Dense(1, activation='sigmoid'))
     model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
     return model

# Define the hyperparameter grid
param_dist = {
    'state_dim': [20, 50, 100, 200, 500],
    'learning_rate': [0.01, 0.001, 0.0001],
    'dropout_rate': [0.2, 0.3, 0.5],
    'batch_size': [32, 64, 128],
    'epochs': [5, 10, 15]
}

# Wrap the Keras model for use with scikit-learn
keras_model = KerasClassifier(build_fn=create_model, verbose=2)

# Create RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=keras_model, param_distributions=param_dist, cv=2, n_iter=10)

# Fit the model
random_search.fit(train_rev_pad, train_sent, validation_split=validation_split, batch_size=batch_size, epochs=epochs, shuffle=True)

# Convert the results to a pandas DataFrame
results_df = pd.DataFrame(random_search.cv_results_)

# Print the DataFrame
print("Results stored in DataFrame:")
print(results_df)

# Print best hyperparameters
print("Best Hyperparameters:", random_search.best_params_)

# Get and print the best test accuracy
best_accuracy = random_search.score(test_rev_pad, test_sent)
print("Best Test Accuracy:", best_accuracy)
# Out:
# <ipython-input-15-cf707c4838c1>:26: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=create_model, verbose=2)
# Epoch 1/5
# 360/360 - 98s - loss: 0.5575 - accuracy: 0.7514 - val_loss: 0.4080 - val_accuracy: 0.8473 - 98s/epoch - 273ms/step
# Epoch 2/5
# 360/360 - 94s - loss: 0.2940 - accuracy: 0.8960 - val_loss: 0.3324 - val_accuracy: 0.8669 - 94s/epoch - 261ms/step
# Epoch 3/5
# 360/360 - 94s - loss: 0.1837 - accuracy: 0.9426 - val_loss: 0.3577 - val_accuracy: 0.8553 - 94s/epoch - 260ms/step
# Epoch 4/5
# 360/360 - 94s - loss: 0.1219 - accuracy: 0.9672 - val_loss: 0.3808 - val_accuracy: 0.8553 - 94s/epoch - 262ms/step
# Epoch 5/5
# 360/360 - 94s - loss: 0.0815 - accuracy: 0.9813 - val_loss: 0.4599 - val_accuracy: 0.8478 - 94s/epoch - 261ms/step
# 352/352 - 17s - loss: 0.4656 - accuracy: 0.8425 - 17s/epoch - 49ms/step
# Epoch 1/5
# 360/360 - 100s - loss: 0.5559 - accuracy: 0.7265 - val_loss: 0.4188 - val_accuracy: 0.8387 - 100s/epoch - 277ms/step
# Epoch 2/5
# 360/360 - 97s - loss: 0.3145 - accuracy: 0.8936 - val_loss: 0.3444 - val_accuracy: 0.8598 - 97s/epoch - 269ms/step
# Epoch 3/5
# 360/360 - 96s - loss: 0.1945 - accuracy: 0.9394 - val_loss: 0.3421 - val_accuracy: 0.8616 - 96s/epoch - 267ms/step
# Epoch 4/5
# 360/360 - 97s - loss: 0.1265 - accuracy: 0.9641 - val_loss: 0.4058 - val_accuracy: 0.8562 - 97s/epoch - 268ms/step
# Epoch 5/5
# 360/360 - 96s - loss: 0.0871 - accuracy: 0.9791 - val_loss: 0.4567 - val_accuracy: 0.8440 - 96s/epoch - 265ms/step
# 352/352 - 17s - loss: 0.4624 - accuracy: 0.8436 - 17s/epoch - 49ms/step
# Epoch 1/5
# 360/360 - 99s - loss: 0.3632 - accuracy: 0.8390 - val_loss: 0.2825 - val_accuracy: 0.8860 - 99s/epoch - 276ms/step
# Epoch 2/5
# 360/360 - 95s - loss: 0.1451 - accuracy: 0.9492 - val_loss: 0.3193 - val_accuracy: 0.8698 - 95s/epoch - 265ms/step
# Epoch 3/5
# 360/360 - 94s - loss: 0.0686 - accuracy: 0.9768 - val_loss: 0.4841 - val_accuracy: 0.8604 - 94s/epoch - 262ms/step
# Epoch 4/5
# 360/360 - 94s - loss: 0.0373 - accuracy: 0.9888 - val_loss: 0.5790 - val_accuracy: 0.8529 - 94s/epoch - 261ms/step
# Epoch 5/5
# 360/360 - 94s - loss: 0.0241 - accuracy: 0.9928 - val_loss: 0.6732 - val_accuracy: 0.8544 - 94s/epoch - 262ms/step
# 352/352 - 17s - loss: 0.6992 - accuracy: 0.8487 - 17s/epoch - 50ms/step
# Epoch 1/5
# 360/360 - 98s - loss: 0.3748 - accuracy: 0.8352 - val_loss: 0.2941 - val_accuracy: 0.8824 - 98s/epoch - 274ms/step
# Epoch 2/5
# 360/360 - 95s - loss: 0.1439 - accuracy: 0.9514 - val_loss: 0.2998 - val_accuracy: 0.8793 - 95s/epoch - 264ms/step
# Epoch 3/5
# 360/360 - 96s - loss: 0.0705 - accuracy: 0.9799 - val_loss: 0.4941 - val_accuracy: 0.8618 - 96s/epoch - 266ms/step
# Epoch 4/5
# 360/360 - 97s - loss: 0.0407 - accuracy: 0.9883 - val_loss: 0.4820 - val_accuracy: 0.8573 - 97s/epoch - 268ms/step
# Epoch 5/5
# 360/360 - 97s - loss: 0.0205 - accuracy: 0.9933 - val_loss: 0.6527 - val_accuracy: 0.8538 - 97s/epoch - 269ms/step
# 352/352 - 18s - loss: 0.6864 - accuracy: 0.8426 - 18s/epoch - 51ms/step
# Epoch 1/5
# 360/360 - 99s - loss: 0.5144 - accuracy: 0.7769 - val_loss: 0.3812 - val_accuracy: 0.8640 - 99s/epoch - 276ms/step
# Epoch 2/5
# 360/360 - 97s - loss: 0.2518 - accuracy: 0.9101 - val_loss: 0.3188 - val_accuracy: 0.8673 - 97s/epoch - 268ms/step
# Epoch 3/5
# 360/360 - 96s - loss: 0.1421 - accuracy: 0.9559 - val_loss: 0.3827 - val_accuracy: 0.8573 - 96s/epoch - 267ms/step
# Epoch 4/5
# 360/360 - 96s - loss: 0.0817 - accuracy: 0.9768 - val_loss: 0.5232 - val_accuracy: 0.8433 - 96s/epoch - 267ms/step
# Epoch 5/5
# 360/360 - 96s - loss: 0.0441 - accuracy: 0.9891 - val_loss: 0.7102 - val_accuracy: 0.8322 - 96s/epoch - 268ms/step
# 176/176 - 9s - loss: 0.7182 - accuracy: 0.8310 - 9s/epoch - 52ms/step
# Epoch 1/5
# 360/360 - 100s - loss: 0.5365 - accuracy: 0.7506 - val_loss: 0.3772 - val_accuracy: 0.8551 - 100s/epoch - 278ms/step
# Epoch 2/5
# 360/360 - 97s - loss: 0.2650 - accuracy: 0.9057 - val_loss: 0.3202 - val_accuracy: 0.8660 - 97s/epoch - 269ms/step
# Epoch 3/5
# 360/360 - 97s - loss: 0.1557 - accuracy: 0.9499 - val_loss: 0.4069 - val_accuracy: 0.8531 - 97s/epoch - 269ms/step
# Epoch 4/5
# 360/360 - 96s - loss: 0.0934 - accuracy: 0.9739 - val_loss: 0.3456 - val_accuracy: 0.8580 - 96s/epoch - 267ms/step
# Epoch 5/5
# 360/360 - 95s - loss: 0.0577 - accuracy: 0.9853 - val_loss: 0.6338 - val_accuracy: 0.8362 - 95s/epoch - 263ms/step
# 176/176 - 9s - loss: 0.6405 - accuracy: 0.8330 - 9s/epoch - 53ms/step
# Epoch 1/5
# 360/360 - 97s - loss: 0.3540 - accuracy: 0.8471 - val_loss: 0.2969 - val_accuracy: 0.8867 - 97s/epoch - 268ms/step
# Epoch 2/5
# 360/360 - 94s - loss: 0.1130 - accuracy: 0.9617 - val_loss: 0.3798 - val_accuracy: 0.8676 - 94s/epoch - 260ms/step
# Epoch 3/5
# 360/360 - 94s - loss: 0.0301 - accuracy: 0.9908 - val_loss: 0.5694 - val_accuracy: 0.8598 - 94s/epoch - 260ms/step
# Epoch 4/5
# 360/360 - 93s - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.7177 - val_accuracy: 0.8462 - 93s/epoch - 258ms/step
# Epoch 5/5
# 360/360 - 92s - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.7917 - val_accuracy: 0.8624 - 92s/epoch - 255ms/step
# 176/176 - 9s - loss: 0.7921 - accuracy: 0.8648 - 9s/epoch - 50ms/step
# Epoch 1/5
# 360/360 - 97s - loss: 0.3500 - accuracy: 0.8508 - val_loss: 0.2801 - val_accuracy: 0.8884 - 97s/epoch - 269ms/step
# Epoch 2/5
# 360/360 - 93s - loss: 0.1181 - accuracy: 0.9593 - val_loss: 0.3465 - val_accuracy: 0.8713 - 93s/epoch - 259ms/step
# Epoch 3/5
# 360/360 - 94s - loss: 0.0301 - accuracy: 0.9908 - val_loss: 0.5164 - val_accuracy: 0.8682 - 94s/epoch - 260ms/step
# Epoch 4/5
# 360/360 - 93s - loss: 0.0094 - accuracy: 0.9977 - val_loss: 0.6112 - val_accuracy: 0.8709 - 93s/epoch - 259ms/step
# Epoch 5/5
# 360/360 - 94s - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.7509 - val_accuracy: 0.8651 - 94s/epoch - 260ms/step
# 176/176 - 9s - loss: 0.7542 - accuracy: 0.8615 - 9s/epoch - 51ms/step
# Epoch 1/5
# 360/360 - 98s - loss: 0.3905 - accuracy: 0.8295 - val_loss: 0.2933 - val_accuracy: 0.8776 - 98s/epoch - 272ms/step
# Epoch 2/5
# 360/360 - 94s - loss: 0.1580 - accuracy: 0.9454 - val_loss: 0.3234 - val_accuracy: 0.8733 - 94s/epoch - 262ms/step
# Epoch 3/5
# 360/360 - 94s - loss: 0.0690 - accuracy: 0.9791 - val_loss: 0.3977 - val_accuracy: 0.8622 - 94s/epoch - 261ms/step
# Epoch 4/5
# 360/360 - 94s - loss: 0.0383 - accuracy: 0.9883 - val_loss: 0.6412 - val_accuracy: 0.8504 - 94s/epoch - 261ms/step
# Epoch 5/5
# 360/360 - 94s - loss: 0.0271 - accuracy: 0.9912 - val_loss: 0.5974 - val_accuracy: 0.8602 - 94s/epoch - 261ms/step
# 176/176 - 9s - loss: 0.6200 - accuracy: 0.8549 - 9s/epoch - 53ms/step
# Epoch 1/5
# 360/360 - 98s - loss: 0.3769 - accuracy: 0.8372 - val_loss: 0.2934 - val_accuracy: 0.8762 - 98s/epoch - 272ms/step
# Epoch 2/5
# 360/360 - 93s - loss: 0.1464 - accuracy: 0.9502 - val_loss: 0.3283 - val_accuracy: 0.8711 - 93s/epoch - 259ms/step
# Epoch 3/5
# 360/360 - 95s - loss: 0.0673 - accuracy: 0.9790 - val_loss: 0.3744 - val_accuracy: 0.8711 - 95s/epoch - 263ms/step
# Epoch 4/5
# 360/360 - 95s - loss: 0.0387 - accuracy: 0.9879 - val_loss: 0.5568 - val_accuracy: 0.8582 - 95s/epoch - 265ms/step
# Epoch 5/5
# 360/360 - 96s - loss: 0.0307 - accuracy: 0.9922 - val_loss: 0.6088 - val_accuracy: 0.8589 - 96s/epoch - 267ms/step
# 176/176 - 9s - loss: 0.6045 - accuracy: 0.8553 - 9s/epoch - 53ms/step
# Epoch 1/5
# 360/360 - 102s - loss: 0.5681 - accuracy: 0.7606 - val_loss: 0.4453 - val_accuracy: 0.8382 - 102s/epoch - 284ms/step
# Epoch 2/5
# 360/360 - 98s - loss: 0.3339 - accuracy: 0.8896 - val_loss: 0.3724 - val_accuracy: 0.8562 - 98s/epoch - 271ms/step
# Epoch 3/5
# 360/360 - 97s - loss: 0.2164 - accuracy: 0.9359 - val_loss: 0.3599 - val_accuracy: 0.8591 - 97s/epoch - 270ms/step
# Epoch 4/5
# 360/360 - 97s - loss: 0.1430 - accuracy: 0.9620 - val_loss: 0.4208 - val_accuracy: 0.8471 - 97s/epoch - 269ms/step
# Epoch 5/5
# 360/360 - 97s - loss: 0.0981 - accuracy: 0.9769 - val_loss: 0.4502 - val_accuracy: 0.8431 - 97s/epoch - 269ms/step
# 352/352 - 17s - loss: 0.4517 - accuracy: 0.8392 - 17s/epoch - 49ms/step
# Epoch 1/5
# 360/360 - 100s - loss: 0.5678 - accuracy: 0.7529 - val_loss: 0.4249 - val_accuracy: 0.8380 - 100s/epoch - 278ms/step
# Epoch 2/5
# 360/360 - 95s - loss: 0.3203 - accuracy: 0.8928 - val_loss: 0.3345 - val_accuracy: 0.8640 - 95s/epoch - 265ms/step
# Epoch 3/5
# 360/360 - 96s - loss: 0.2063 - accuracy: 0.9373 - val_loss: 0.3307 - val_accuracy: 0.8616 - 96s/epoch - 265ms/step
# Epoch 4/5
# 360/360 - 96s - loss: 0.1380 - accuracy: 0.9623 - val_loss: 0.3681 - val_accuracy: 0.8531 - 96s/epoch - 267ms/step
# Epoch 5/5
# 360/360 - 96s - loss: 0.0940 - accuracy: 0.9777 - val_loss: 0.4466 - val_accuracy: 0.8458 - 96s/epoch - 266ms/step
# 352/352 - 17s - loss: 0.4483 - accuracy: 0.8429 - 17s/epoch - 49ms/step
# Epoch 1/5
# 360/360 - 97s - loss: 0.4021 - accuracy: 0.8354 - val_loss: 0.3080 - val_accuracy: 0.8684 - 97s/epoch - 268ms/step
# Epoch 2/5
# 360/360 - 93s - loss: 0.1750 - accuracy: 0.9391 - val_loss: 0.3555 - val_accuracy: 0.8578 - 93s/epoch - 257ms/step
# Epoch 3/5
# 360/360 - 91s - loss: 0.0830 - accuracy: 0.9751 - val_loss: 0.4071 - val_accuracy: 0.8538 - 91s/epoch - 253ms/step
# Epoch 4/5
# 360/360 - 91s - loss: 0.0412 - accuracy: 0.9884 - val_loss: 0.5580 - val_accuracy: 0.8393 - 91s/epoch - 254ms/step
# Epoch 5/5
# 360/360 - 92s - loss: 0.0264 - accuracy: 0.9934 - val_loss: 0.6211 - val_accuracy: 0.8444 - 92s/epoch - 257ms/step
# 176/176 - 9s - loss: 0.6398 - accuracy: 0.8391 - 9s/epoch - 51ms/step
# Epoch 1/5
# 360/360 - 96s - loss: 0.3983 - accuracy: 0.8351 - val_loss: 0.3072 - val_accuracy: 0.8756 - 96s/epoch - 266ms/step
# Epoch 2/5
# 360/360 - 91s - loss: 0.1723 - accuracy: 0.9427 - val_loss: 0.3142 - val_accuracy: 0.8693 - 91s/epoch - 254ms/step
# Epoch 3/5
# 360/360 - 92s - loss: 0.0817 - accuracy: 0.9753 - val_loss: 0.4075 - val_accuracy: 0.8564 - 92s/epoch - 255ms/step
# Epoch 4/5
# 360/360 - 92s - loss: 0.0451 - accuracy: 0.9866 - val_loss: 0.4550 - val_accuracy: 0.8576 - 92s/epoch - 255ms/step
# Epoch 5/5
# 360/360 - 91s - loss: 0.0289 - accuracy: 0.9931 - val_loss: 0.4344 - val_accuracy: 0.8551 - 91s/epoch - 253ms/step
# 176/176 - 9s - loss: 0.4390 - accuracy: 0.8492 - 9s/epoch - 51ms/step
# Epoch 1/5
# 360/360 - 99s - loss: 0.3802 - accuracy: 0.8314 - val_loss: 0.2794 - val_accuracy: 0.8918 - 99s/epoch - 276ms/step
# Epoch 2/5
# 360/360 - 96s - loss: 0.1294 - accuracy: 0.9538 - val_loss: 0.3318 - val_accuracy: 0.8727 - 96s/epoch - 268ms/step
# Epoch 3/5
# 360/360 - 95s - loss: 0.0378 - accuracy: 0.9876 - val_loss: 0.5287 - val_accuracy: 0.8500 - 95s/epoch - 265ms/step
# Epoch 4/5
# 360/360 - 95s - loss: 0.0117 - accuracy: 0.9966 - val_loss: 0.6575 - val_accuracy: 0.8678 - 95s/epoch - 265ms/step
# Epoch 5/5
# 360/360 - 96s - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.9367 - val_accuracy: 0.8627 - 96s/epoch - 266ms/step
# 704/704 - 34s - loss: 0.9607 - accuracy: 0.8543 - 34s/epoch - 48ms/step
# Epoch 1/5
# 360/360 - 99s - loss: 0.3652 - accuracy: 0.8409 - val_loss: 0.2889 - val_accuracy: 0.8862 - 99s/epoch - 276ms/step
# Epoch 2/5
# 360/360 - 96s - loss: 0.1269 - accuracy: 0.9563 - val_loss: 0.3310 - val_accuracy: 0.8742 - 96s/epoch - 266ms/step
# Epoch 3/5
# 360/360 - 96s - loss: 0.0390 - accuracy: 0.9872 - val_loss: 0.4773 - val_accuracy: 0.8640 - 96s/epoch - 266ms/step
# Epoch 4/5
# 360/360 - 96s - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.6473 - val_accuracy: 0.8622 - 96s/epoch - 266ms/step
# Epoch 5/5
# 360/360 - 96s - loss: 0.0073 - accuracy: 0.9982 - val_loss: 0.6846 - val_accuracy: 0.8631 - 96s/epoch - 266ms/step
# 704/704 - 34s - loss: 0.6914 - accuracy: 0.8593 - 34s/epoch - 48ms/step
# Epoch 1/5
# 360/360 - 99s - loss: 0.3543 - accuracy: 0.8428 - val_loss: 0.2807 - val_accuracy: 0.8871 - 99s/epoch - 275ms/step
# Epoch 2/5
# 360/360 - 95s - loss: 0.1088 - accuracy: 0.9627 - val_loss: 0.3466 - val_accuracy: 0.8736 - 95s/epoch - 265ms/step
# Epoch 3/5
# 360/360 - 95s - loss: 0.0294 - accuracy: 0.9910 - val_loss: 0.4648 - val_accuracy: 0.8611 - 95s/epoch - 264ms/step
# Epoch 4/5
# 360/360 - 95s - loss: 0.0092 - accuracy: 0.9978 - val_loss: 0.5918 - val_accuracy: 0.8647 - 95s/epoch - 265ms/step
# Epoch 5/5
# 360/360 - 95s - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.7640 - val_accuracy: 0.8693 - 95s/epoch - 264ms/step
# 352/352 - 17s - loss: 0.8041 - accuracy: 0.8663 - 17s/epoch - 47ms/step
# Epoch 1/5
# 360/360 - 99s - loss: 0.3605 - accuracy: 0.8427 - val_loss: 0.2886 - val_accuracy: 0.8809 - 99s/epoch - 276ms/step
# Epoch 2/5
# 360/360 - 95s - loss: 0.1155 - accuracy: 0.9613 - val_loss: 0.3695 - val_accuracy: 0.8691 - 95s/epoch - 264ms/step
# Epoch 3/5
# 360/360 - 95s - loss: 0.0310 - accuracy: 0.9914 - val_loss: 0.5959 - val_accuracy: 0.8547 - 95s/epoch - 263ms/step
# Epoch 4/5
# 360/360 - 94s - loss: 0.0088 - accuracy: 0.9979 - val_loss: 0.7169 - val_accuracy: 0.8616 - 94s/epoch - 262ms/step
# Epoch 5/5
# 360/360 - 95s - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.7475 - val_accuracy: 0.8456 - 95s/epoch - 264ms/step
# 352/352 - 17s - loss: 0.7822 - accuracy: 0.8392 - 17s/epoch - 48ms/step
# Epoch 1/5
# 360/360 - 98s - loss: 0.3661 - accuracy: 0.8424 - val_loss: 0.2780 - val_accuracy: 0.8840 - 98s/epoch - 272ms/step
# Epoch 2/5
# 360/360 - 95s - loss: 0.1152 - accuracy: 0.9599 - val_loss: 0.3323 - val_accuracy: 0.8696 - 95s/epoch - 264ms/step
# Epoch 3/5
# 360/360 - 96s - loss: 0.0325 - accuracy: 0.9903 - val_loss: 0.4849 - val_accuracy: 0.8753 - 96s/epoch - 265ms/step
# Epoch 4/5
# 360/360 - 94s - loss: 0.0124 - accuracy: 0.9964 - val_loss: 0.6810 - val_accuracy: 0.8600 - 94s/epoch - 261ms/step
# Epoch 5/5
# 360/360 - 94s - loss: 0.0075 - accuracy: 0.9982 - val_loss: 0.6342 - val_accuracy: 0.8656 - 94s/epoch - 260ms/step
# 176/176 - 9s - loss: 0.6848 - accuracy: 0.8616 - 9s/epoch - 50ms/step
# Epoch 1/5
# 360/360 - 100s - loss: 0.3729 - accuracy: 0.8435 - val_loss: 0.2925 - val_accuracy: 0.8827 - 100s/epoch - 278ms/step
# Epoch 2/5
# 360/360 - 95s - loss: 0.1255 - accuracy: 0.9571 - val_loss: 0.3431 - val_accuracy: 0.8696 - 95s/epoch - 264ms/step
# Epoch 3/5
# 360/360 - 94s - loss: 0.0409 - accuracy: 0.9872 - val_loss: 0.5221 - val_accuracy: 0.8609 - 94s/epoch - 262ms/step
# Epoch 4/5
# 360/360 - 94s - loss: 0.0144 - accuracy: 0.9963 - val_loss: 0.6658 - val_accuracy: 0.8636 - 94s/epoch - 260ms/step
# Epoch 5/5
# 360/360 - 94s - loss: 0.0082 - accuracy: 0.9978 - val_loss: 0.7601 - val_accuracy: 0.8631 - 94s/epoch - 261ms/step
# 176/176 - 9s - loss: 0.7637 - accuracy: 0.8593 - 9s/epoch - 51ms/step
# Epoch 1/5
# 720/720 - 191s - loss: 0.3108 - accuracy: 0.8694 - val_loss: 0.2712 - val_accuracy: 0.8902 - 191s/epoch - 265ms/step
# Epoch 2/5
# 720/720 - 189s - loss: 0.1296 - accuracy: 0.9527 - val_loss: 0.2968 - val_accuracy: 0.8847 - 189s/epoch - 263ms/step
# Epoch 3/5
# 720/720 - 191s - loss: 0.0548 - accuracy: 0.9821 - val_loss: 0.3978 - val_accuracy: 0.8851 - 191s/epoch - 265ms/step
# Epoch 4/5
# 720/720 - 192s - loss: 0.0271 - accuracy: 0.9912 - val_loss: 0.5124 - val_accuracy: 0.8792 - 192s/epoch - 266ms/step
# Epoch 5/5
# 720/720 - 189s - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.6203 - val_accuracy: 0.8764 - 189s/epoch - 262ms/step
# Results stored in DataFrame:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     480.499628      5.437080        17.206931        0.048109
# 1     481.595571      2.385730        17.709530        0.175213
# 2     485.921007      0.015318         9.283140        0.139139
# 3     470.558610      1.147852         8.920143        0.144601
# 4     476.978567      1.592518         9.332614        0.024864
# 5     487.890819      3.923235        17.230218        0.004569
# 6     464.027350      1.209472         9.088590        0.006867
# 7     483.420502      0.008789        33.962139        0.082435
# 8     479.952341      0.609005        16.757134        0.054132
# 9     477.447774      0.345384         8.884313        0.052378
#
#   param_state_dim param_learning_rate param_epochs param_dropout_rate  \
# 0              50              0.0001           10                0.3
# 1             200               0.001           15                0.2
# 2             200              0.0001            5                0.2
# 3             100                0.01           15                0.2
# 4             500               0.001           10                0.3
# 5              50              0.0001            5                0.5
# 6              20               0.001            5                0.3
# 7             200                0.01           10                0.5
# 8              50                0.01           15                0.2
# 9              50                0.01           15                0.5
#
#   param_batch_size                                             params  \
# 0               64  {'state_dim': 50, 'learning_rate': 0.0001, 'ep...
# 1               64  {'state_dim': 200, 'learning_rate': 0.001, 'ep...
# 2              128  {'state_dim': 200, 'learning_rate': 0.0001, 'e...
# 3              128  {'state_dim': 100, 'learning_rate': 0.01, 'epo...
# 4              128  {'state_dim': 500, 'learning_rate': 0.001, 'ep...
# 5               64  {'state_dim': 50, 'learning_rate': 0.0001, 'ep...
# 6              128  {'state_dim': 20, 'learning_rate': 0.001, 'epo...
# 7               32  {'state_dim': 200, 'learning_rate': 0.01, 'epo...
# 8               64  {'state_dim': 50, 'learning_rate': 0.01, 'epoc...
# 9              128  {'state_dim': 50, 'learning_rate': 0.01, 'epoc...
#
#    split0_test_score  split1_test_score  mean_test_score  std_test_score  \
# 0           0.842489           0.843644         0.843067        0.000578
# 1           0.848711           0.842622         0.845667        0.003044
# 2           0.831022           0.832978         0.832000        0.000978
# 3           0.864756           0.861511         0.863133        0.001622
# 4           0.854933           0.855333         0.855133        0.000200
# 5           0.839200           0.842933         0.841067        0.001867
# 6           0.839111           0.849156         0.844133        0.005022
# 7           0.854267           0.859333         0.856800        0.002533
# 8           0.866267           0.839244         0.852756        0.013511
# 9           0.861556           0.859289         0.860422        0.001133
#
#    rank_test_score
# 0                8
# 1                6
# 2               10
# 3                1
# 4                4
# 5                9
# 6                7
# 7                3
# 8                5
# 9                2
# Best Hyperparameters: {'state_dim': 100, 'learning_rate': 0.01, 'epochs': 15, 'dropout_rate': 0.2, 'batch_size': 128}
# 40/40 - 3s - loss: 0.5579 - accuracy: 0.8892 - 3s/epoch - 74ms/step
# Best Test Accuracy: 0.88919997215271

# %%
from google.colab import files
results_df.to_csv('LSTM_Hypertuning.csv')
files.download('LSTM_Hypertuning.csv')

# %% [markdown]
# **Tuning Hyper parameters of RNN Model**

# %%
validation_split = 0.2
batch_size = 50
epochs = 5

# Define a function to create the model
def create_model(state_dim, learning_rate, dropout_rate, batch_size, epochs):
     model = Sequential()
     model.add(Embedding(len(tokenizer.word_index)+1, embedding_dimension, input_length=upper_bound, weights=[embedding_matrix], trainable=True, mask_zero=True))
     model.add(SimpleRNN(state_dim, return_sequences=True))
     model.add(GlobalAveragePooling1D())
     model.add(Dropout(dropout_rate))
     model.add(Dense(1, activation='sigmoid'))
     model.compile(optimizer=Adam(learning_rate=learning_rate), loss='binary_crossentropy', metrics=['accuracy'])
     return model

# Define the hyperparameter grid
param_dist = {
    'state_dim': [20, 50, 100, 200, 500],
    'learning_rate': [0.01, 0.001, 0.0001],
    'dropout_rate': [0.2, 0.3, 0.5],
    'batch_size': [32, 64, 128],
    'epochs': [5, 10, 15]
}

# Wrap the Keras model for use with scikit-learn
keras_model = KerasClassifier(build_fn=create_model, verbose=2)

# Create RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=keras_model, param_distributions=param_dist, cv=2, n_iter=10)

# Fit the model
random_search.fit(train_rev_pad, train_sent, validation_split=validation_split, batch_size=batch_size, epochs=epochs, shuffle=True)

# Convert the results to a pandas DataFrame
result_df = pd.DataFrame(random_search.cv_results_)

# Print the DataFrame
print("Results stored in DataFrame:")
print(result_df)

# Print best hyperparameters
print("Best Hyperparameters:", random_search.best_params_)

# Get and print the best test accuracy
best_accuracy = random_search.score(test_rev_pad, test_sent)
print("Best Test Accuracy:", best_accuracy)
# Out:
# <ipython-input-16-ba61f972ecd8>:26: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   keras_model = KerasClassifier(build_fn=create_model, verbose=2)
# Epoch 1/5
# 360/360 - 71s - loss: 0.3797 - accuracy: 0.8372 - val_loss: 0.2997 - val_accuracy: 0.8738 - 71s/epoch - 197ms/step
# Epoch 2/5
# 360/360 - 69s - loss: 0.1465 - accuracy: 0.9493 - val_loss: 0.3387 - val_accuracy: 0.8642 - 69s/epoch - 192ms/step
# Epoch 3/5
# 360/360 - 69s - loss: 0.0678 - accuracy: 0.9797 - val_loss: 0.4375 - val_accuracy: 0.8580 - 69s/epoch - 191ms/step
# Epoch 4/5
# 360/360 - 69s - loss: 0.0345 - accuracy: 0.9899 - val_loss: 0.6502 - val_accuracy: 0.8511 - 69s/epoch - 192ms/step
# Epoch 5/5
# 360/360 - 69s - loss: 0.0208 - accuracy: 0.9939 - val_loss: 0.6226 - val_accuracy: 0.8469 - 69s/epoch - 193ms/step
# 704/704 - 20s - loss: 0.6216 - accuracy: 0.8554 - 20s/epoch - 29ms/step
# Epoch 1/5
# 360/360 - 70s - loss: 0.3756 - accuracy: 0.8393 - val_loss: 0.2890 - val_accuracy: 0.8789 - 70s/epoch - 196ms/step
# Epoch 2/5
# 360/360 - 69s - loss: 0.1408 - accuracy: 0.9529 - val_loss: 0.3610 - val_accuracy: 0.8702 - 69s/epoch - 192ms/step
# Epoch 3/5
# 360/360 - 70s - loss: 0.0664 - accuracy: 0.9807 - val_loss: 0.3578 - val_accuracy: 0.8660 - 70s/epoch - 193ms/step
# Epoch 4/5
# 360/360 - 69s - loss: 0.0383 - accuracy: 0.9898 - val_loss: 0.5030 - val_accuracy: 0.8653 - 69s/epoch - 192ms/step
# Epoch 5/5
# 360/360 - 69s - loss: 0.0201 - accuracy: 0.9951 - val_loss: 0.4565 - val_accuracy: 0.8604 - 69s/epoch - 191ms/step
# 704/704 - 20s - loss: 0.4801 - accuracy: 0.8494 - 20s/epoch - 28ms/step
# Epoch 1/5
# 360/360 - 70s - loss: 0.3700 - accuracy: 0.8359 - val_loss: 0.2941 - val_accuracy: 0.8858 - 70s/epoch - 195ms/step
# Epoch 2/5
# 360/360 - 70s - loss: 0.1392 - accuracy: 0.9511 - val_loss: 0.3326 - val_accuracy: 0.8713 - 70s/epoch - 194ms/step
# Epoch 3/5
# 360/360 - 70s - loss: 0.0611 - accuracy: 0.9815 - val_loss: 0.4915 - val_accuracy: 0.8582 - 70s/epoch - 193ms/step
# Epoch 4/5
# 360/360 - 70s - loss: 0.0382 - accuracy: 0.9899 - val_loss: 0.8181 - val_accuracy: 0.8560 - 70s/epoch - 193ms/step
# Epoch 5/5
# 360/360 - 70s - loss: 0.0271 - accuracy: 0.9931 - val_loss: 0.5970 - val_accuracy: 0.8587 - 70s/epoch - 195ms/step
# 352/352 - 11s - loss: 0.6027 - accuracy: 0.8590 - 11s/epoch - 31ms/step
# Epoch 1/5
# 360/360 - 72s - loss: 0.3870 - accuracy: 0.8297 - val_loss: 0.3000 - val_accuracy: 0.8813 - 72s/epoch - 201ms/step
# Epoch 2/5
# 360/360 - 70s - loss: 0.1467 - accuracy: 0.9505 - val_loss: 0.3386 - val_accuracy: 0.8749 - 70s/epoch - 194ms/step
# Epoch 3/5
# 360/360 - 70s - loss: 0.0583 - accuracy: 0.9839 - val_loss: 0.4137 - val_accuracy: 0.8718 - 70s/epoch - 195ms/step
# Epoch 4/5
# 360/360 - 70s - loss: 0.0358 - accuracy: 0.9904 - val_loss: 0.6023 - val_accuracy: 0.8642 - 70s/epoch - 195ms/step
# Epoch 5/5
# 360/360 - 70s - loss: 0.0278 - accuracy: 0.9930 - val_loss: 0.5651 - val_accuracy: 0.8649 - 70s/epoch - 194ms/step
# 352/352 - 11s - loss: 0.5820 - accuracy: 0.8538 - 11s/epoch - 31ms/step
# Epoch 1/5
# 360/360 - 70s - loss: 0.5642 - accuracy: 0.7717 - val_loss: 0.5265 - val_accuracy: 0.8151 - 70s/epoch - 195ms/step
# Epoch 2/5
# 360/360 - 69s - loss: 0.4085 - accuracy: 0.8653 - val_loss: 0.4408 - val_accuracy: 0.8193 - 69s/epoch - 191ms/step
# Epoch 3/5
# 360/360 - 69s - loss: 0.3421 - accuracy: 0.8963 - val_loss: 0.4541 - val_accuracy: 0.8024 - 69s/epoch - 191ms/step
# Epoch 4/5
# 360/360 - 69s - loss: 0.2708 - accuracy: 0.9274 - val_loss: 0.4093 - val_accuracy: 0.8233 - 69s/epoch - 192ms/step
# Epoch 5/5
# 360/360 - 70s - loss: 0.2182 - accuracy: 0.9466 - val_loss: 0.4263 - val_accuracy: 0.8169 - 70s/epoch - 193ms/step
# 704/704 - 20s - loss: 0.4283 - accuracy: 0.8163 - 20s/epoch - 28ms/step
# Epoch 1/5
# 360/360 - 69s - loss: 0.6151 - accuracy: 0.7414 - val_loss: 0.5573 - val_accuracy: 0.7613 - 69s/epoch - 192ms/step
# Epoch 2/5
# 360/360 - 68s - loss: 0.4605 - accuracy: 0.8388 - val_loss: 0.4458 - val_accuracy: 0.8267 - 68s/epoch - 188ms/step
# Epoch 3/5
# 360/360 - 68s - loss: 0.3143 - accuracy: 0.9070 - val_loss: 0.3732 - val_accuracy: 0.8498 - 68s/epoch - 190ms/step
# Epoch 4/5
# 360/360 - 70s - loss: 0.2240 - accuracy: 0.9411 - val_loss: 0.3758 - val_accuracy: 0.8427 - 70s/epoch - 193ms/step
# Epoch 5/5
# 360/360 - 68s - loss: 0.1705 - accuracy: 0.9556 - val_loss: 0.3649 - val_accuracy: 0.8493 - 68s/epoch - 189ms/step
# 704/704 - 20s - loss: 0.3794 - accuracy: 0.8379 - 20s/epoch - 28ms/step
# Epoch 1/5
# 360/360 - 70s - loss: 0.4251 - accuracy: 0.8168 - val_loss: 0.3218 - val_accuracy: 0.8649 - 70s/epoch - 193ms/step
# Epoch 2/5
# 360/360 - 68s - loss: 0.1974 - accuracy: 0.9317 - val_loss: 0.3228 - val_accuracy: 0.8736 - 68s/epoch - 189ms/step
# Epoch 3/5
# 360/360 - 68s - loss: 0.1057 - accuracy: 0.9679 - val_loss: 0.3866 - val_accuracy: 0.8558 - 68s/epoch - 188ms/step
# Epoch 4/5
# 360/360 - 69s - loss: 0.0647 - accuracy: 0.9831 - val_loss: 0.4241 - val_accuracy: 0.8511 - 69s/epoch - 191ms/step
# Epoch 5/5
# 360/360 - 68s - loss: 0.0459 - accuracy: 0.9872 - val_loss: 0.4974 - val_accuracy: 0.8491 - 68s/epoch - 190ms/step
# 704/704 - 20s - loss: 0.5089 - accuracy: 0.8518 - 20s/epoch - 28ms/step
# Epoch 1/5
# 360/360 - 73s - loss: 0.4359 - accuracy: 0.8147 - val_loss: 0.3222 - val_accuracy: 0.8689 - 73s/epoch - 202ms/step
# Epoch 2/5
# 360/360 - 70s - loss: 0.2013 - accuracy: 0.9331 - val_loss: 0.3144 - val_accuracy: 0.8696 - 70s/epoch - 196ms/step
# Epoch 3/5
# 360/360 - 72s - loss: 0.1144 - accuracy: 0.9673 - val_loss: 0.3863 - val_accuracy: 0.8598 - 72s/epoch - 200ms/step
# Epoch 4/5
# 360/360 - 72s - loss: 0.0977 - accuracy: 0.9769 - val_loss: 0.4354 - val_accuracy: 0.8551 - 72s/epoch - 199ms/step
# Epoch 5/5
# 360/360 - 70s - loss: 0.0540 - accuracy: 0.9866 - val_loss: 0.5297 - val_accuracy: 0.8504 - 70s/epoch - 195ms/step
# 704/704 - 20s - loss: 0.5258 - accuracy: 0.8490 - 20s/epoch - 29ms/step
# Epoch 1/5
# 360/360 - 72s - loss: 0.5222 - accuracy: 0.7641 - val_loss: 0.3636 - val_accuracy: 0.8422 - 72s/epoch - 200ms/step
# Epoch 2/5
# 360/360 - 71s - loss: 0.2451 - accuracy: 0.9098 - val_loss: 0.3945 - val_accuracy: 0.8396 - 71s/epoch - 198ms/step
# Epoch 3/5
# 360/360 - 71s - loss: 0.2141 - accuracy: 0.9271 - val_loss: 0.3916 - val_accuracy: 0.8364 - 71s/epoch - 197ms/step
# Epoch 4/5
# 360/360 - 71s - loss: 0.1756 - accuracy: 0.9367 - val_loss: 0.4275 - val_accuracy: 0.8309 - 71s/epoch - 197ms/step
# Epoch 5/5
# 360/360 - 71s - loss: 0.1678 - accuracy: 0.9386 - val_loss: 0.4848 - val_accuracy: 0.8238 - 71s/epoch - 197ms/step
# 704/704 - 20s - loss: 0.4524 - accuracy: 0.8364 - 20s/epoch - 28ms/step
# Epoch 1/5
# 360/360 - 73s - loss: 0.3886 - accuracy: 0.8304 - val_loss: 0.3083 - val_accuracy: 0.8824 - 73s/epoch - 202ms/step
# Epoch 2/5
# 360/360 - 70s - loss: 0.1639 - accuracy: 0.9439 - val_loss: 0.3492 - val_accuracy: 0.8758 - 70s/epoch - 195ms/step
# Epoch 3/5
# 360/360 - 71s - loss: 0.0814 - accuracy: 0.9738 - val_loss: 0.4025 - val_accuracy: 0.8716 - 71s/epoch - 198ms/step
# Epoch 4/5
# 360/360 - 72s - loss: 0.0553 - accuracy: 0.9832 - val_loss: 0.4777 - val_accuracy: 0.8640 - 72s/epoch - 199ms/step
# Epoch 5/5
# 360/360 - 72s - loss: 0.0317 - accuracy: 0.9913 - val_loss: 0.6020 - val_accuracy: 0.8631 - 72s/epoch - 199ms/step
# 704/704 - 20s - loss: 0.6196 - accuracy: 0.8549 - 20s/epoch - 28ms/step
# Epoch 1/5
# 360/360 - 70s - loss: 0.5362 - accuracy: 0.7902 - val_loss: 0.3858 - val_accuracy: 0.8533 - 70s/epoch - 195ms/step
# Epoch 2/5
# 360/360 - 69s - loss: 0.3064 - accuracy: 0.8978 - val_loss: 0.3495 - val_accuracy: 0.8544 - 69s/epoch - 191ms/step
# Epoch 3/5
# 360/360 - 69s - loss: 0.2166 - accuracy: 0.9355 - val_loss: 0.3675 - val_accuracy: 0.8458 - 69s/epoch - 192ms/step
# Epoch 4/5
# 360/360 - 69s - loss: 0.1637 - accuracy: 0.9526 - val_loss: 0.4222 - val_accuracy: 0.8336 - 69s/epoch - 191ms/step
# Epoch 5/5
# 360/360 - 68s - loss: 0.1338 - accuracy: 0.9641 - val_loss: 0.4029 - val_accuracy: 0.8418 - 68s/epoch - 190ms/step
# 176/176 - 5s - loss: 0.4183 - accuracy: 0.8363 - 5s/epoch - 30ms/step
# Epoch 1/5
# 360/360 - 71s - loss: 0.6042 - accuracy: 0.7280 - val_loss: 0.5467 - val_accuracy: 0.7576 - 71s/epoch - 196ms/step
# Epoch 2/5
# 360/360 - 69s - loss: 0.4037 - accuracy: 0.8696 - val_loss: 0.3854 - val_accuracy: 0.8540 - 69s/epoch - 193ms/step
# Epoch 3/5
# 360/360 - 70s - loss: 0.2723 - accuracy: 0.9213 - val_loss: 0.3776 - val_accuracy: 0.8444 - 70s/epoch - 195ms/step
# Epoch 4/5
# 360/360 - 70s - loss: 0.2022 - accuracy: 0.9481 - val_loss: 0.3817 - val_accuracy: 0.8416 - 70s/epoch - 194ms/step
# Epoch 5/5
# 360/360 - 70s - loss: 0.1512 - accuracy: 0.9654 - val_loss: 0.4187 - val_accuracy: 0.8318 - 70s/epoch - 194ms/step
# 176/176 - 5s - loss: 0.4168 - accuracy: 0.8301 - 5s/epoch - 30ms/step
# Epoch 1/5
# 360/360 - 71s - loss: 0.3949 - accuracy: 0.8251 - val_loss: 0.2906 - val_accuracy: 0.8796 - 71s/epoch - 198ms/step
# Epoch 2/5
# 360/360 - 70s - loss: 0.1481 - accuracy: 0.9477 - val_loss: 0.3410 - val_accuracy: 0.8762 - 70s/epoch - 196ms/step
# Epoch 3/5
# 360/360 - 70s - loss: 0.0626 - accuracy: 0.9814 - val_loss: 0.3940 - val_accuracy: 0.8611 - 70s/epoch - 195ms/step
# Epoch 4/5
# 360/360 - 71s - loss: 0.0323 - accuracy: 0.9910 - val_loss: 0.7275 - val_accuracy: 0.8549 - 71s/epoch - 196ms/step
# Epoch 5/5
# 360/360 - 70s - loss: 0.0176 - accuracy: 0.9951 - val_loss: 0.9295 - val_accuracy: 0.8489 - 70s/epoch - 194ms/step
# 352/352 - 11s - loss: 0.9374 - accuracy: 0.8486 - 11s/epoch - 30ms/step
# Epoch 1/5
# 360/360 - 71s - loss: 0.4021 - accuracy: 0.8249 - val_loss: 0.3226 - val_accuracy: 0.8824 - 71s/epoch - 197ms/step
# Epoch 2/5
# 360/360 - 70s - loss: 0.1523 - accuracy: 0.9499 - val_loss: 0.3304 - val_accuracy: 0.8731 - 70s/epoch - 194ms/step
# Epoch 3/5
# 360/360 - 70s - loss: 0.0613 - accuracy: 0.9824 - val_loss: 0.5126 - val_accuracy: 0.8667 - 70s/epoch - 195ms/step
# Epoch 4/5
# 360/360 - 70s - loss: 0.0358 - accuracy: 0.9902 - val_loss: 0.6707 - val_accuracy: 0.8598 - 70s/epoch - 193ms/step
# Epoch 5/5
# 360/360 - 70s - loss: 0.0263 - accuracy: 0.9928 - val_loss: 0.5996 - val_accuracy: 0.8604 - 70s/epoch - 194ms/step
# 352/352 - 11s - loss: 0.6031 - accuracy: 0.8571 - 11s/epoch - 31ms/step
# Epoch 1/5
# 360/360 - 70s - loss: 0.4676 - accuracy: 0.8201 - val_loss: 0.3453 - val_accuracy: 0.8569 - 70s/epoch - 193ms/step
# Epoch 2/5
# 360/360 - 69s - loss: 0.2226 - accuracy: 0.9207 - val_loss: 0.3363 - val_accuracy: 0.8598 - 69s/epoch - 191ms/step
# Epoch 3/5
# 360/360 - 68s - loss: 0.1228 - accuracy: 0.9594 - val_loss: 0.3784 - val_accuracy: 0.8591 - 68s/epoch - 188ms/step
# Epoch 4/5
# 360/360 - 68s - loss: 0.0702 - accuracy: 0.9802 - val_loss: 0.4120 - val_accuracy: 0.8536 - 68s/epoch - 189ms/step
# Epoch 5/5
# 360/360 - 68s - loss: 0.0442 - accuracy: 0.9890 - val_loss: 0.5066 - val_accuracy: 0.8509 - 68s/epoch - 190ms/step
# 352/352 - 10s - loss: 0.5355 - accuracy: 0.8433 - 10s/epoch - 28ms/step
# Epoch 1/5
# 360/360 - 73s - loss: 0.4337 - accuracy: 0.8097 - val_loss: 0.3065 - val_accuracy: 0.8791 - 73s/epoch - 202ms/step
# Epoch 2/5
# 360/360 - 71s - loss: 0.1884 - accuracy: 0.9351 - val_loss: 0.3060 - val_accuracy: 0.8744 - 71s/epoch - 196ms/step
# Epoch 3/5
# 360/360 - 70s - loss: 0.0947 - accuracy: 0.9722 - val_loss: 0.4135 - val_accuracy: 0.8611 - 70s/epoch - 196ms/step
# Epoch 4/5
# 360/360 - 71s - loss: 0.0500 - accuracy: 0.9873 - val_loss: 0.4469 - val_accuracy: 0.8611 - 71s/epoch - 197ms/step
# Epoch 5/5
# 360/360 - 71s - loss: 0.0389 - accuracy: 0.9900 - val_loss: 0.4588 - val_accuracy: 0.8562 - 71s/epoch - 196ms/step
# 352/352 - 10s - loss: 0.4746 - accuracy: 0.8529 - 10s/epoch - 29ms/step
# Epoch 1/5
# 360/360 - 73s - loss: 0.4321 - accuracy: 0.7956 - val_loss: 0.2938 - val_accuracy: 0.8809 - 73s/epoch - 204ms/step
# Epoch 2/5
# 360/360 - 73s - loss: 0.1651 - accuracy: 0.9430 - val_loss: 0.3006 - val_accuracy: 0.8844 - 73s/epoch - 203ms/step
# Epoch 3/5
# 360/360 - 73s - loss: 0.0741 - accuracy: 0.9774 - val_loss: 0.4372 - val_accuracy: 0.8642 - 73s/epoch - 202ms/step
# Epoch 4/5
# 360/360 - 73s - loss: 0.0377 - accuracy: 0.9889 - val_loss: 0.5679 - val_accuracy: 0.8582 - 73s/epoch - 202ms/step
# Epoch 5/5
# 360/360 - 73s - loss: 0.0212 - accuracy: 0.9939 - val_loss: 1.0007 - val_accuracy: 0.8491 - 73s/epoch - 204ms/step
# 352/352 - 11s - loss: 1.0625 - accuracy: 0.8492 - 11s/epoch - 31ms/step
# Epoch 1/5
# 360/360 - 74s - loss: 0.6846 - accuracy: 0.6029 - val_loss: 0.4891 - val_accuracy: 0.7349 - 74s/epoch - 207ms/step
# Epoch 2/5
# 360/360 - 72s - loss: 0.2709 - accuracy: 0.8954 - val_loss: 0.3010 - val_accuracy: 0.8809 - 72s/epoch - 201ms/step
# Epoch 3/5
# 360/360 - 73s - loss: 0.1137 - accuracy: 0.9624 - val_loss: 0.3001 - val_accuracy: 0.8787 - 73s/epoch - 203ms/step
# Epoch 4/5
# 360/360 - 73s - loss: 0.0849 - accuracy: 0.9814 - val_loss: 0.3636 - val_accuracy: 0.8731 - 73s/epoch - 203ms/step
# Epoch 5/5
# 360/360 - 73s - loss: 0.0441 - accuracy: 0.9899 - val_loss: 0.4411 - val_accuracy: 0.8607 - 73s/epoch - 202ms/step
# 352/352 - 11s - loss: 0.4566 - accuracy: 0.8568 - 11s/epoch - 31ms/step
# Epoch 1/5
# 360/360 - 70s - loss: 0.4086 - accuracy: 0.8221 - val_loss: 0.3532 - val_accuracy: 0.8511 - 70s/epoch - 195ms/step
# Epoch 2/5
# 360/360 - 69s - loss: 0.2429 - accuracy: 0.9062 - val_loss: 0.4045 - val_accuracy: 0.8362 - 69s/epoch - 190ms/step
# Epoch 3/5
# 360/360 - 69s - loss: 0.2049 - accuracy: 0.9208 - val_loss: 0.4445 - val_accuracy: 0.8358 - 69s/epoch - 193ms/step
# Epoch 4/5
# 360/360 - 69s - loss: 0.1608 - accuracy: 0.9399 - val_loss: 0.4814 - val_accuracy: 0.8380 - 69s/epoch - 191ms/step
# Epoch 5/5
# 360/360 - 69s - loss: 0.1156 - accuracy: 0.9592 - val_loss: 0.5517 - val_accuracy: 0.8302 - 69s/epoch - 191ms/step
# 352/352 - 10s - loss: 0.5469 - accuracy: 0.8324 - 10s/epoch - 29ms/step
# Epoch 1/5
# 360/360 - 70s - loss: 0.3743 - accuracy: 0.8424 - val_loss: 0.3084 - val_accuracy: 0.8762 - 70s/epoch - 194ms/step
# Epoch 2/5
# 360/360 - 69s - loss: 0.1651 - accuracy: 0.9422 - val_loss: 0.3600 - val_accuracy: 0.8651 - 69s/epoch - 192ms/step
# Epoch 3/5
# 360/360 - 69s - loss: 0.0739 - accuracy: 0.9772 - val_loss: 0.4204 - val_accuracy: 0.8633 - 69s/epoch - 190ms/step
# Epoch 4/5
# 360/360 - 69s - loss: 0.0395 - accuracy: 0.9884 - val_loss: 0.5857 - val_accuracy: 0.8582 - 69s/epoch - 192ms/step
# Epoch 5/5
# 360/360 - 69s - loss: 0.0186 - accuracy: 0.9948 - val_loss: 0.7005 - val_accuracy: 0.8531 - 69s/epoch - 192ms/step
# 352/352 - 10s - loss: 0.7084 - accuracy: 0.8546 - 10s/epoch - 28ms/step
# Epoch 1/5
# 720/720 - 144s - loss: 0.3451 - accuracy: 0.8566 - val_loss: 0.2683 - val_accuracy: 0.8910 - 144s/epoch - 199ms/step
# Epoch 2/5
# 720/720 - 141s - loss: 0.1670 - accuracy: 0.9412 - val_loss: 0.2869 - val_accuracy: 0.8824 - 141s/epoch - 195ms/step
# Epoch 3/5
# 720/720 - 141s - loss: 0.1075 - accuracy: 0.9631 - val_loss: 0.3870 - val_accuracy: 0.8760 - 141s/epoch - 195ms/step
# Epoch 4/5
# 720/720 - 140s - loss: 0.0770 - accuracy: 0.9759 - val_loss: 0.3732 - val_accuracy: 0.8626 - 140s/epoch - 195ms/step
# Epoch 5/5
# 720/720 - 141s - loss: 0.3400 - accuracy: 0.9304 - val_loss: 0.5845 - val_accuracy: 0.8560 - 141s/epoch - 195ms/step
# Results stored in DataFrame:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0     347.607295      0.157375        19.934972        0.190293
# 1     351.039567      1.283926        10.906775        0.009154
# 2     344.731943      1.693149        19.644109        0.091007
# 3     350.110135      7.184405        20.002516        0.345282
# 4     356.956999      0.676225        19.688363        0.085466
# 5     347.467310      2.456889         5.308216        0.027547
# 6     351.823177      0.872944        10.682201        0.097033
# 7     349.350941      6.789809        10.076917        0.082250
# 8     365.884218      0.105961        10.946178        0.103616
# 9     345.745373      0.015609        10.058393        0.101444
#
#   param_state_dim param_learning_rate param_epochs param_dropout_rate  \
# 0             100               0.001           10                0.2
# 1             200               0.001           10                0.3
# 2              20              0.0001           10                0.2
# 3              20               0.001           10                0.5
# 4             200                0.01            5                0.5
# 5              20              0.0001           15                0.2
# 6             200               0.001           10                0.2
# 7              20               0.001           15                0.3
# 8             500               0.001           10                0.2
# 9             100                0.01           15                0.5
#
#   param_batch_size                                             params  \
# 0               32  {'state_dim': 100, 'learning_rate': 0.001, 'ep...
# 1               64  {'state_dim': 200, 'learning_rate': 0.001, 'ep...
# 2               32  {'state_dim': 20, 'learning_rate': 0.0001, 'ep...
# 3               32  {'state_dim': 20, 'learning_rate': 0.001, 'epo...
# 4               32  {'state_dim': 200, 'learning_rate': 0.01, 'epo...
# 5              128  {'state_dim': 20, 'learning_rate': 0.0001, 'ep...
# 6               64  {'state_dim': 200, 'learning_rate': 0.001, 'ep...
# 7               64  {'state_dim': 20, 'learning_rate': 0.001, 'epo...
# 8               64  {'state_dim': 500, 'learning_rate': 0.001, 'ep...
# 9               64  {'state_dim': 100, 'learning_rate': 0.01, 'epo...
#
#    split0_test_score  split1_test_score  mean_test_score  std_test_score  \
# 0           0.855422           0.849378         0.852400        0.003022
# 1           0.858978           0.853778         0.856378        0.002600
# 2           0.816267           0.837867         0.827067        0.010800
# 3           0.851822           0.849022         0.850422        0.001400
# 4           0.836356           0.854889         0.845622        0.009267
# 5           0.836267           0.830133         0.833200        0.003067
# 6           0.848578           0.857111         0.852844        0.004267
# 7           0.843333           0.852889         0.848111        0.004778
# 8           0.849156           0.856844         0.853000        0.003844
# 9           0.832356           0.854622         0.843489        0.011133
#
#    rank_test_score
# 0                4
# 1                1
# 2               10
# 3                5
# 4                7
# 5                9
# 6                3
# 7                6
# 8                2
# 9                8
# Best Hyperparameters: {'state_dim': 200, 'learning_rate': 0.001, 'epochs': 10, 'dropout_rate': 0.3, 'batch_size': 64}
# 79/79 - 3s - loss: 0.5342 - accuracy: 0.8582 - 3s/epoch - 34ms/step
# Best Test Accuracy: 0.8582000136375427

# %%
from google.colab import files
results_df.to_csv('RNN_Hypertuning.csv')
files.download('RNN_Hypertuning.csv')
